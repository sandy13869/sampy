# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/rajusunkara/Downloads/innomatics/invest'

# %%
data_comp = pd.read_csv("companies.csv")
data_comp
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
data_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
# permalink            66368 non-null object
# name                 66367 non-null object
# homepage_url         61310 non-null object
# category_list        63220 non-null object
# funding_total_usd    66368 non-null object
# status               66368 non-null object
# country_code         59410 non-null object
# state_code           57821 non-null object
# region               58338 non-null object
# city                 58340 non-null object
# funding_rounds       66368 non-null int64
# founded_at           51147 non-null object
# first_funding_at     66344 non-null object
# last_funding_at      66368 non-null object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %%
data_comp["permalink"].nunique()
# Out:
# 66368

# %%
data_comp["name"].nunique()
# Out:
# 66102

# %%
data_comp["category_list"].nunique()
# Out:
# 27296

# %%
data_map = pd.read_csv("mapping.csv")
data_map
# Out:
#                   category_list  Automotive & Sports  Blanks  \
# 0                           NaN                    0       1
# 1                            3D                    0       0
# 2                   3D Printing                    0       0
# 3                 3D Technology                    0       0
# 4                    Accounting                    0       0
# 5              Active Lifestyle                    0       0
# 6                  Ad Targeting                    0       0
# 7            Advanced Materials                    0       0
# 8              Adventure Travel                    1       0
# 9                   Advertising                    0       0
# 10        Advertising Exchanges                    0       0
# 11         Advertising Networks                    0       0
# 12        Advertising Platforms                    0       0
# 13                       Advice                    0       0
# ...

# %%
data_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 10 columns):
# category_list                              687 non-null object
# Automotive & Sports                        688 non-null int64
# Blanks                                     688 non-null int64
# Cleantech / Semiconductors                 688 non-null int64
# Entertainment                              688 non-null int64
# Health                                     688 non-null int64
# Manufacturing                              688 non-null int64
# News, Search and Messaging                 688 non-null int64
# Others                                     688 non-null int64
# Social, Finance, Analytics, Advertising    688 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 53.8+ KB

# %%
data_map["category_list"].nunique()
# Out:
# 687

# %%
data_comp["category_list"].unique() = data_map["category_list"].unique()
# Out:
#   File "<ipython-input-21-ef6019afac3c>", line 1
#     data_comp["category_list"].unique() = data_map["category_list"].unique()
#                                                                             ^
# SyntaxError: can't assign to function call

# %%
data_round = pd.read_excel("rounds2.xls")
data_round.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code  funded_at  raised_amount_usd
# 0                  B 2015-01-05         10000000.0
# 1                  A 2014-10-14                NaN
# 2                NaN 2014-03-01           700000.0
# 3                  B 2014-01-30          3406878.0
# ...

# %%
data_round.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 6 columns):
# company_permalink          65535 non-null object
# funding_round_permalink    65535 non-null object
# funding_round_type         65535 non-null object
# funding_round_code         17734 non-null object
# funded_at                  65535 non-null datetime64[ns]
# raised_amount_usd          54183 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 3.0+ MB

# %%
data_round["company_permalink"].nunique()
# Out:
# 51575

# %%
data_comp["permalink"].nunique()
# Out:
# 66368

# %%
df1 = pd.DataFrame(data_comp["permalink"])
df2 = pd.DataFrame(data_round["company_permalink"])


set(df1.columns).intersection(set(df2.columns))
# Out:
# set()

# %%
df1 = pd.DataFrame(data_comp["permalink"])
df2 = pd.DataFrame(data_round["company_permalink"])

#pd.concat([df1, df2], axis=0)

#set(df1.columns).intersection(set(df2.columns))

df = pd.concat([df1, df2], axis=1)
df.head()
# Out:
#                              permalink                    company_permalink
# 0                  /organization/-fame                  /organization/-fame
# 1               /organization/-qounter               /ORGANIZATION/-QOUNTER
# 2  /organization/-the-one-of-them-inc-               /organization/-qounter
# 3                /organization/0-6-com  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4       /organization/004-technologies                /organization/0-6-com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 2 columns):
# permalink            66368 non-null object
# company_permalink    65535 non-null object
# dtypes: object(2)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#                   permalink                 company_permalink
# count                 66368                             65535
# unique                66368                             51575
# top     /organization/rumpl  /ORGANIZATION/EXAGEN-DIAGNOSTICS
# freq                      1                                 9

# %%
set(df["company_permalink"]).intersection(set(df["permalink"]))
# Out:
# {'/organization/goatapp',
#  '/organization/jelastic',
#  '/organization/iagnosis',
#  '/organization/ginger-software',
#  '/organization/immure-records',
#  '/organization/emulate',
#  '/organization/myokardia',
#  '/organization/aea-technology',
#  '/organization/freakn-genius',
#  '/organization/brilliant-telecom',
#  '/organization/contix',
#  '/organization/apama-medical',
#  '/organization/citious',
#  '/organization/autonavi',
#  '/organization/cardiac-concepts',
#  '/organization/b-bridge-international',
#  '/organization/morphosys',
#  '/organization/adc-therapeutics',
#  '/organization/keukey',
#  '/organization/content-launch',
#  '/organization/getgems',
#  '/organization/agerpoint',
#  '/organization/ez-wheel',
#  '/organization/crowdtwist',
#  '/organization/hoodin',
#  '/organization/hymite',
#  '/organization/innerapps',
#  '/organization/close-communications',
#  '/organization/latest-medical',
#  '/organization/digico-europe',
#  '/organization/livebid',
# ...

# %%
sm = set(df["company_permalink"]).intersection(set(df["permalink"]))
ln = len(sm)
print(ln)
# Out:
# 25769

# %%
master_frame = pd.concat([data_comp, data_round], ignore_index=True)

master_frame.head()
# Out:
# /Users/rajusunkara/Documents/anakonda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                        category_list           city  \
# 0                                              Media         Mumbai
# 1  Application Platforms|Real Time|Social Network...  Delaware City
# 2                                  Apps|Games|Mobile            NaN
# 3                                        Curated Web        Beijing
# 4                                           Software      Champaign
#
#   company_permalink country_code first_funding_at  founded_at funded_at  \
# ...

# %%
master_frame.shape
# Out:
# (131903, 20)

# %%
data_round["funding_round_type"].nunique()
# Out:
# 14

# %%
#data_round.groupby(['funding_round_type','raised_amount_usd']).max()
data_round.groupby('funding_round_type',as_index=False)['raised_amount_usd'].mean()
# Out:
#        funding_round_type  raised_amount_usd
# 0                   angel       1.036442e+06
# 1        convertible_note       1.369433e+06
# 2          debt_financing       1.239184e+07
# 3     equity_crowdfunding       5.935335e+05
# 4                   grant       4.002148e+06
# 5   non_equity_assistance       6.558629e+05
# 6           post_ipo_debt       1.261462e+08
# 7         post_ipo_equity       1.054236e+08
# 8          private_equity       7.333605e+07
# 9    product_crowdfunding       1.257261e+06
# 10       secondary_market       5.992401e+07
# 11                   seed       7.229131e+05
# 12            undisclosed       2.148652e+07
# 13                venture       1.203396e+07

# %%
data_round["raised_amount_usd"]
# Out:
# 0         10000000.0
# 1                NaN
# 2           700000.0
# 3          3406878.0
# 4          2000000.0
# 5                NaN
# 6            41250.0
# 7            43360.0
# 8           719491.0
# 9          3000000.0
# 10        20000000.0
# 11         1700000.0
# 12         8900000.0
# 13          150000.0
# 14               NaN
# 15         1000050.0
# 16           40000.0
# 17               NaN
# 18               NaN
# 19               NaN
# 20         1750000.0
# 21         6000000.0
# 22         5000000.0
# 23          100000.0
# 24          800000.0
# 25          500000.0
# 26          500000.0
# 27          250000.0
# 28         4000000.0
# 29          400000.0
#             ...
# 65505     10000000.0
# 65506            NaN
# 65507     12000000.0
# 65508            NaN
# 65509            NaN
# 65510        25000.0
# 65511      2350000.0
# 65512            NaN
# 65513     51700000.0
# 65514      8500000.0
# 65515     21000000.0
# 65516     25000000.0
# ...

# %%
data_comp["country_code"].unique()
# Out:
# array(['IND', 'USA', nan, 'CHN', 'HKG', 'CAN', 'CHL', 'GBR', 'FRA', 'AUS',
#        'DNK', 'ROM', 'AUT', 'KOR', 'NLD', 'SWE', 'JPN', 'RUS', 'SGP',
#        'NOR', 'COL', 'ESP', 'BEL', 'IRL', 'ITA', 'ISR', 'NZL', 'CZE',
#        'DEU', 'CHE', 'BRA', 'BGR', 'SVN', 'JOR', 'HUN', 'BWA', 'NGA',
#        'FIN', 'TUR', 'IDN', 'ARE', 'CYP', 'POL', 'CRI', 'PRT', 'ARG',
#        'TWN', 'KHM', 'THA', 'SVK', 'UKR', 'LTU', 'ISL', 'ZAF', 'MEX',
#        'VEN', 'URY', 'MUS', 'KEN', 'PHL', 'MNE', 'VNM', 'GHA', 'PSE',
#        'MYS', 'PER', 'EGY', 'PAN', 'LVA', 'GGY', 'ALB', 'UGA', 'HRV',
#        'EST', 'LBN', 'GRC', 'PAK', 'NPL', 'LUX', 'SAU', 'IRN', 'GTM',
#        'BAH', 'ARM', 'BGD', 'MDA', 'SRB', 'TUN', 'ZWE', 'BRB', 'NIC',
#        'TAN', 'PRI', 'TTO', 'BHR', 'CMR', 'BLR', 'CYM', 'BRN', 'ECU',
#        'SLV', 'MLT', 'ZMB', 'MKD', 'GIB', 'TGO', 'LAO', 'BMU', 'HND',
#        'MCO', 'MMR', 'KAZ', 'QAT', 'DOM', 'MAR', 'LIE', 'GEO', 'MOZ',
# ...

# %%
data_comp["country_code"].value_counts()
# Out:
# USA    37601
# GBR     3688
# CAN     1925
# IND     1596
# CHN     1544
# FRA     1135
# DEU     1082
# ISR      965
# ESP      746
# AUS      503
# NLD      497
# RUS      458
# SGP      455
# SWE      452
# BRA      446
# IRL      440
# JPN      411
# ITA      404
# KOR      362
# CHE      335
# CHL      332
# DNK      311
# FIN      283
# HKG      209
# BEL      205
# ARG      186
# TUR      178
# POL      150
# MEX      145
# NOR      134
#        ...
# NIC        2
# GIB        2
# ALB        2
# BLZ        2
# MOZ        2
# KWT        2
# CIV        2
# PSE        2
# HND        2
# SOM        1
# SEN        1
# GRD        1
# SYC        1
# UZB        1
# IRN        1
# BRB        1
# BRN        1
# KNA        1
# QAT        1
# JEY        1
# GGY        1
# BLM        1
# TGO        1
# DZA        1
# MNE        1
# MAF        1
# OMN        1
# DMA        1
# KAZ        1
# PRY        1
# Name: country_code, Length: 137, dtype: int64

# %%
data_comp.groupby('country_code',as_index=False)['funding_total_usd'].max()
# Out:
#     country_code funding_total_usd
# 0            ALB       276744.1287
# 1            ARE            998999
# 2            ARG             97643
# 3            ARM          26517500
# 4            AUS            985095
# 5            AUT           9664366
# 6            AZE            200000
# 7            BAH           8900000
# 8            BEL           9980000
# 9            BGD            750000
# 10           BGR           9300000
# 11           BHR             76269
# 12           BLM            350000
# 13           BLR             90000
# 14           BLZ              4299
# 15           BMU           5300000
# 16           BRA             97560
# 17           BRB           1500000
# 18           BRN                 -
# 19           BWA            750000
# 20           CAN           9911648
# 21           CHE       98201432.23
# 22           CHL             94583
# 23           CHN          99000000
# 24           CIV             60000
# 25           CMR              4561
# ...

# %%
data_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
# permalink            66368 non-null object
# name                 66367 non-null object
# homepage_url         61310 non-null object
# category_list        63220 non-null object
# funding_total_usd    66368 non-null object
# status               66368 non-null object
# country_code         59410 non-null object
# state_code           57821 non-null object
# region               58338 non-null object
# city                 58340 non-null object
# funding_rounds       66368 non-null int64
# founded_at           51147 non-null object
# first_funding_at     66344 non-null object
# last_funding_at      66368 non-null object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %%
data_round.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 6 columns):
# company_permalink          65535 non-null object
# funding_round_permalink    65535 non-null object
# funding_round_type         65535 non-null object
# funding_round_code         17734 non-null object
# funded_at                  65535 non-null datetime64[ns]
# raised_amount_usd          54183 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 3.0+ MB

# %%
data_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 10 columns):
# category_list                              687 non-null object
# Automotive & Sports                        688 non-null int64
# Blanks                                     688 non-null int64
# Cleantech / Semiconductors                 688 non-null int64
# Entertainment                              688 non-null int64
# Health                                     688 non-null int64
# Manufacturing                              688 non-null int64
# News, Search and Messaging                 688 non-null int64
# Others                                     688 non-null int64
# Social, Finance, Analytics, Advertising    688 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 53.8+ KB

# %%
data_comp["funding_total_usd"]
# Out:
# 0          10000000
# 1            700000
# 2           3406878
# 3           2000000
# 4                 -
# 5             41250
# 6            762851
# 7          33600000
# 8           1150050
# 9             40000
# 10                -
# 11                -
# 12                -
# 13          1750000
# 14          6000000
# 15          5000000
# 16           100000
# 17          2050000
# 18          4400000
# 19            40000
# 20           500000
# 21         43923865
# 22                -
# 23          2535000
# 24          6795451
# 25       10661772.9
# 26          8900000
# 27         10000000
# 28          3000000
# 29          4500000
#             ...
# 66338        800000
# 66339         75000
# 66340        666154
# 66341      12039999
# 66342      44000000
# 66343       2257464
# 66344      64674400
# 66345             -
# 66346             -
# 66347             -
# 66348        198493
# 66349       3805520
# 66350      13000000
# 66351             -
# ...

# %%
data_comp["funding_totals"]=data_comp["funding_total_usd"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-1446a124788a> in <module>()
# ----> 1 data_comp["funding_totals"]=data_comp["funding_total_usd"].astype(int)
#
# ~/Documents/anakonda/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~/Documents/anakonda/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
# ...

# %%
data_comp['funding_total_usd'].astype(str).astype(int)
tot = data_comp['funding_total_usd'].sum()
print(tot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-394a6a6af703> in <module>()
# ----> 1 data_comp['funding_total_usd'].astype(str).astype(int)
#       2 tot = data_comp['funding_total_usd'].sum()
#       3 print(tot)
#
# ~/Documents/anakonda/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~/Documents/anakonda/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...
