# %% [markdown]
# # Matplotlib
#
# - Visualizations

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
# Output of plotting commands is displayed inline

# %%
fig = plt.figure()
ax = plt.axes()

# %%
#np.linspace(0, 10, 1000)

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %% [markdown]
# #### If we want to create a single figure with multiple lines, we can simply call the plot function multiple times

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# ### These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK) color systems,commonly used for digital color graphics.

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# # Labeling

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend()

# %% [markdown]
# # Histograms

# %%
import pandas as pd
dataset=pd.read_csv('./sales.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
# Sales Executive    20 non-null int64
# Name               20 non-null object
# Gender             20 non-null object
# Age                20 non-null int64
# Location           20 non-null object
# Sales ( in Rs)     20 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 1.0+ KB

# %%
dataset.keys()
# Out:
# Index(['Sales Executive', 'Name', 'Gender', 'Age', 'Location',
#        'Sales ( in Rs)'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Sales Executive    0
# Name               0
# Gender             0
# Age                0
# Location           0
# Sales ( in Rs)     0
# dtype: int64

# %%
dataset.head(2)
# Out:
#    Sales Executive    Name Gender  Age   Location  Sales ( in Rs)
# 0                1  Mahesh   Male   25  Hyderabad              50
# 1                2  Suresh   Male   22  Hyderabad              75

# %%
dataset.plot('Name','Age', kind='bar')

# %%
plt.bar([5,8,10],[4,6,8])
# Out:
# <BarContainer object of 3 artists>

# %%
dataset.head(3).plot('Name','Age', kind='bar')

# %%
dataset.head(3).plot('Name','Age',kind='pie')

# %% [markdown]
# # Box Plot

# %%
dataset.plot.box(by='Sales Executive')

# %% [markdown]
# # Heatmap

# %%
import seaborn as sns
import numpy as np

# %%
#uniform_data = np.random.rand(10, 12)
#uniform_data

# %%
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)
plt.show()

# %%
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
x = [5,8,10]
y = [12,16,6]
plt.plot(x,y)

# %% [markdown]
# #### Apply names to axis and plot

# %%
from matplotlib import style
style.use('ggplot')

x = [1,25,9]
y = [12,2,15]

x2 = [2,29,10]
y2 = [6,15,7]

plt.plot(x,y,linewidth=5)
plt.plot(x2,y2,linewidth=5)

plt.title('ggplot')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
x = [1,25,9]
y = [12,2,15]

x2 = [2,29,10]
y2 = [6,15,7]

plt.plot(x,y,'g',label = 'Red',linewidth=5)
plt.plot(x2,y2,'c',label= 'Blue',linewidth=5)

plt.title('')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.legend()

plt.grid(True, color='k')

plt.show()

# %%
x = [1,25,9]
y = [12,2,15]

x2 = [2,29,10]
y2 = [6,15,7]

plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g',align='center')

plt.title('Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
x = [1,25,9]
y = [12,2,15]

x2 = [2,29,10]
y2 = [6,15,7]

plt.scatter(x,y,color='y')
plt.scatter(x2,y2, color='r')

plt.title('')
plt.ylabel('Y axis')
plt.xlabel('X axis')


plt.show()

# %%
import numpy as np

# %%
x,y = np.loadtxt('example.csv',unpack=True, delimiter=',')
plt.plot(x,y)

plt.title('')
plt.ylabel('Y axis')
plt.xlabel('X axis')


plt.show()
