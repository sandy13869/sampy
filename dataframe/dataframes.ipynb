# %%
import os
os.getcwd()
# Out:
# '/Users/rajusunkara/Downloads/innomatics/dataframe'

# %%
os.chdir("/Users/rajusunkara/Downloads/innomatics/dataframe/dataframe")
os.getcwd()
# Out:
# '/Users/rajusunkara/Downloads/innomatics/dataframe/dataframe'

# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("sales.csv")
data1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales ( in Rs)
# 0                 1     Mahesh    Male   25  Hyderabad              50
# 1                 2     Suresh    Male   22  Hyderabad              75
# 2                 3      Vijay    Male   20  Bangalore              11
# 3                 4     Ramesh    Male   27  Bangalore              77
# 4                 5   Jagadish    Male   28     Mumbai              45
# 5                 6     Harish    Male   24  Hyderabad              52
# 6                 7      Karan    Male   24  Bangalore              26
# 7                 8       Raju    Male   23     Mumbai              24
# 8                 9       Maya  Female   24     Mumbai              28
# 9                10       Rani  Female   30     Mumbai              31
# 10               11    Lakshmi  Female   19  Bangalore              36
# 11               12      Roopa  Female   24  Hyderabad              72
# ...

# %%
data2=pd.read_csv('semicolon_separated.txt')
data2
# Out:
#   rollno;name;course
# 0          1;a;btech
# 1          2;b;mtech
# 2            3;c;phd

# %%
data2=pd.read_csv('semicolon_separated.txt',sep=';')
data2
# Out:
#    rollno name course
# 0       1    a  btech
# 1       2    b  mtech
# 2       3    c    phd

# %%
data3=pd.read_csv('tab_separated.txt')
data3
# Out:
#   rollno\tname\tcourse
# 0          1\ta\tbtech
# 1          2\tb\tmtech
# 2            3\tc\tphd

# %%
data3=pd.read_csv('tab_separated.txt',sep='\t')
data3
# Out:
#    rollno name course
# 0       1    a  btech
# 1       2    b  mtech
# 2       3    c    phd

# %%
data4 = pd.read_csv('sales.csv',nrows=4)
data4
# Out:
#    Sales Executive    Name Gender  Age   Location  Sales ( in Rs)
# 0                1  Mahesh   Male   25  Hyderabad              50
# 1                2  Suresh   Male   22  Hyderabad              75
# 2                3   Vijay   Male   20  Bangalore              11
# 3                4  Ramesh   Male   27  Bangalore              77

# %%
data55 = pd.read_csv('sales.csv',nrows=10)
data55.head()
# Out:
#    Sales Executive      Name Gender  Age   Location  Sales ( in Rs)
# 0                1    Mahesh   Male   25  Hyderabad              50
# 1                2    Suresh   Male   22  Hyderabad              75
# 2                3     Vijay   Male   20  Bangalore              11
# 3                4    Ramesh   Male   27  Bangalore              77
# 4                5  Jagadish   Male   28     Mumbai              45

# %%
data5 = pd.read_csv('sales.csv',skiprows=1)
data5
# Out:
#      1     Mahesh    Male  25  Hyderabad  50
# 0    2     Suresh    Male  22  Hyderabad  75
# 1    3      Vijay    Male  20  Bangalore  11
# 2    4     Ramesh    Male  27  Bangalore  77
# 3    5   Jagadish    Male  28     Mumbai  45
# 4    6     Harish    Male  24  Hyderabad  52
# 5    7      Karan    Male  24  Bangalore  26
# 6    8       Raju    Male  23     Mumbai  24
# 7    9       Maya  Female  24     Mumbai  28
# 8   10       Rani  Female  30     Mumbai  31
# 9   11    Lakshmi  Female  19  Bangalore  36
# 10  12      Roopa  Female  24  Hyderabad  72
# 11  13     Sravya  Female  26  Hyderabad  69
# 12  14     Sruthi  Female  26  Hyderabad  51
# 13  15     Swetha  Female  21  Bangalore  34
# 14  16  Aishwarya  Female  24  Bangalore  40
# 15  17    Madhavi  Female  29     Mumbai  18
# 16  18     Rajini  Female  27     Mumbai  35
# 17  19    Haritha  Female  24  Hyderabad  29
# 18  20     Swathi  Female  25  Hyderabad  68

# %%
data6 = pd.read_csv('sales.csv',names='Sales_Executive Name Gender Age Location Sales(in.Rs).split()')
data6
# Out:
# /Users/rajusunkara/Documents/anakonda/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#                   S          a       l    e          s               _   E  \
# 0   Sales Executive       Name  Gender  Age   Location  Sales ( in Rs) NaN
# 1                 1     Mahesh    Male   25  Hyderabad              50 NaN
# 2                 2     Suresh    Male   22  Hyderabad              75 NaN
# 3                 3      Vijay    Male   20  Bangalore              11 NaN
# 4                 4     Ramesh    Male   27  Bangalore              77 NaN
# 5                 5   Jagadish    Male   28     Mumbai              45 NaN
# 6                 6     Harish    Male   24  Hyderabad              52 NaN
# 7                 7      Karan    Male   24  Bangalore              26 NaN
# 8                 8       Raju    Male   23     Mumbai              24 NaN
# ...

# %%
data5 = read.csv("sales.csv",)

# %%
data7 = pd.read_csv('sales.csv',skiprows=1)
data7
# Out:
#      1     Mahesh    Male  25  Hyderabad  50
# 0    2     Suresh    Male  22  Hyderabad  75
# 1    3      Vijay    Male  20  Bangalore  11
# 2    4     Ramesh    Male  27  Bangalore  77
# 3    5   Jagadish    Male  28     Mumbai  45
# 4    6     Harish    Male  24  Hyderabad  52
# 5    7      Karan    Male  24  Bangalore  26
# 6    8       Raju    Male  23     Mumbai  24
# 7    9       Maya  Female  24     Mumbai  28
# 8   10       Rani  Female  30     Mumbai  31
# 9   11    Lakshmi  Female  19  Bangalore  36
# 10  12      Roopa  Female  24  Hyderabad  72
# 11  13     Sravya  Female  26  Hyderabad  69
# 12  14     Sruthi  Female  26  Hyderabad  51
# 13  15     Swetha  Female  21  Bangalore  34
# 14  16  Aishwarya  Female  24  Bangalore  40
# 15  17    Madhavi  Female  29     Mumbai  18
# 16  18     Rajini  Female  27     Mumbai  35
# 17  19    Haritha  Female  24  Hyderabad  29
# 18  20     Swathi  Female  25  Hyderabad  68

# %%
data7 = pd.read_csv('sales.csv',names=['Sales_Executive','Name','Gender','Age','Location','Sales(in.Rs)'])
data7
# Out:
#     Sales_Executive       Name  Gender  Age   Location    Sales(in.Rs)
# 0   Sales Executive       Name  Gender  Age   Location  Sales ( in Rs)
# 1                 1     Mahesh    Male   25  Hyderabad              50
# 2                 2     Suresh    Male   22  Hyderabad              75
# 3                 3      Vijay    Male   20  Bangalore              11
# 4                 4     Ramesh    Male   27  Bangalore              77
# 5                 5   Jagadish    Male   28     Mumbai              45
# 6                 6     Harish    Male   24  Hyderabad              52
# 7                 7      Karan    Male   24  Bangalore              26
# 8                 8       Raju    Male   23     Mumbai              24
# 9                 9       Maya  Female   24     Mumbai              28
# 10               10       Rani  Female   30     Mumbai              31
# 11               11    Lakshmi  Female   19  Bangalore              36
# ...

# %%
data1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales ( in Rs)
# 0                 1     Mahesh    Male   25  Hyderabad              50
# 1                 2     Suresh    Male   22  Hyderabad              75
# 2                 3      Vijay    Male   20  Bangalore              11
# 3                 4     Ramesh    Male   27  Bangalore              77
# 4                 5   Jagadish    Male   28     Mumbai              45
# 5                 6     Harish    Male   24  Hyderabad              52
# 6                 7      Karan    Male   24  Bangalore              26
# 7                 8       Raju    Male   23     Mumbai              24
# 8                 9       Maya  Female   24     Mumbai              28
# 9                10       Rani  Female   30     Mumbai              31
# 10               11    Lakshmi  Female   19  Bangalore              36
# 11               12      Roopa  Female   24  Hyderabad              72
# ...

# %%
data1['Sales ( in Rs)'].max()
# Out:
# 77

# %%
data1.describe()
# Out:
#        Sales Executive        Age  Sales ( in Rs)
# count         20.00000  20.000000       20.000000
# mean          10.50000  24.600000       43.550000
# std            5.91608   2.835861       19.974918
# min            1.00000  19.000000       11.000000
# 25%            5.75000  23.750000       28.750000
# 50%           10.50000  24.000000       38.000000
# 75%           15.25000  26.250000       56.000000
# max           20.00000  30.000000       77.000000

# %%
data1.boxplot(column='Sales ( in Rs)', by = 'Location')

# %%
data1.boxplot(column='Age')

# %%
data1.Location.value_counts()
# Out:
# Hyderabad    8
# Bangalore    6
# Mumbai       6
# Name: Location, dtype: int64

# %%
data1.Gender.value_counts()
# Out:
# Female    12
# Male       8
# Name: Gender, dtype: int64

# %%
data1.head() # Top rows default is 5 records
# Out:
#    Sales Executive      Name Gender  Age   Location  Sales ( in Rs)
# 0                1    Mahesh   Male   25  Hyderabad              50
# 1                2    Suresh   Male   22  Hyderabad              75
# 2                3     Vijay   Male   20  Bangalore              11
# 3                4    Ramesh   Male   27  Bangalore              77
# 4                5  Jagadish   Male   28     Mumbai              45

# %%
data1.head(4)
# Out:
#    Sales Executive    Name Gender  Age   Location  Sales ( in Rs)
# 0                1  Mahesh   Male   25  Hyderabad              50
# 1                2  Suresh   Male   22  Hyderabad              75
# 2                3   Vijay   Male   20  Bangalore              11
# 3                4  Ramesh   Male   27  Bangalore              77

# %%
data1.tail()  # Bottom rows default is 5
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales ( in Rs)
# 15               16  Aishwarya  Female   24  Bangalore              40
# 16               17    Madhavi  Female   29     Mumbai              18
# 17               18     Rajini  Female   27     Mumbai              35
# 18               19    Haritha  Female   24  Hyderabad              29
# 19               20     Swathi  Female   25  Hyderabad              68

# %%
data1.tail(2)
# Out:
#     Sales Executive     Name  Gender  Age   Location  Sales ( in Rs)
# 18               19  Haritha  Female   24  Hyderabad              29
# 19               20   Swathi  Female   25  Hyderabad              68

# %%
data1.info() # Info of all column lable datatypes,column NOs,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
# Sales Executive    20 non-null int64
# Name               20 non-null object
# Gender             20 non-null object
# Age                20 non-null int64
# Location           20 non-null object
# Sales ( in Rs)     20 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 1.0+ KB

# %%
data1.dtypes  # to get uniqu column datatypes
# Out:
# Sales Executive     int64
# Name               object
# Gender             object
# Age                 int64
# Location           object
# Sales ( in Rs)      int64
# dtype: object

# %%
data1.columns
# Out:
# Index(['Sales Executive', 'Name', 'Gender', 'Age', 'Location',
#        'Sales ( in Rs)'],
#       dtype='object')

# %%
data1.shape
# Out:
# (20, 6)

# %%
data1['Age']
# Out:
# 0     25
# 1     22
# 2     20
# 3     27
# 4     28
# 5     24
# 6     24
# 7     23
# 8     24
# 9     30
# 10    19
# 11    24
# 12    26
# 13    26
# 14    21
# 15    24
# 16    29
# 17    27
# 18    24
# 19    25
# Name: Age, dtype: int64

# %%
data1['Age'].unique()
# Out:
# array([25, 22, 20, 27, 28, 24, 23, 30, 19, 26, 21, 29])

# %%
data1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data1['Location'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai'], dtype=object)

# %%
data1.rename(columns={'Sales ( in Rs)':'Sales'},inplace=True)
data1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales
# 0                 1     Mahesh    Male   25  Hyderabad     50
# 1                 2     Suresh    Male   22  Hyderabad     75
# 2                 3      Vijay    Male   20  Bangalore     11
# 3                 4     Ramesh    Male   27  Bangalore     77
# 4                 5   Jagadish    Male   28     Mumbai     45
# 5                 6     Harish    Male   24  Hyderabad     52
# 6                 7      Karan    Male   24  Bangalore     26
# 7                 8       Raju    Male   23     Mumbai     24
# 8                 9       Maya  Female   24     Mumbai     28
# 9                10       Rani  Female   30     Mumbai     31
# 10               11    Lakshmi  Female   19  Bangalore     36
# 11               12      Roopa  Female   24  Hyderabad     72
# 12               13     Sravya  Female   26  Hyderabad     69
# 13               14     Sruthi  Female   26  Hyderabad     51
# ...

# %% [markdown]
# ### Creating new coulmn

# %%
data1['Profit'] = pd.Series(np.random.random(20))

# %%
data1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales    Profit
# 0                 1     Mahesh    Male   25  Hyderabad     50  0.094004
# 1                 2     Suresh    Male   22  Hyderabad     75  0.928577
# 2                 3      Vijay    Male   20  Bangalore     11  0.577858
# 3                 4     Ramesh    Male   27  Bangalore     77  0.169468
# 4                 5   Jagadish    Male   28     Mumbai     45  0.417484
# 5                 6     Harish    Male   24  Hyderabad     52  0.307628
# 6                 7      Karan    Male   24  Bangalore     26  0.560716
# 7                 8       Raju    Male   23     Mumbai     24  0.759146
# 8                 9       Maya  Female   24     Mumbai     28  0.642712
# 9                10       Rani  Female   30     Mumbai     31  0.422763
# 10               11    Lakshmi  Female   19  Bangalore     36  0.366823
# 11               12      Roopa  Female   24  Hyderabad     72  0.609996
# ...

# %% [markdown]
# ### Finding the missing value

# %%
data1.isnull()
# Out:
#     Sales Executive   Name  Gender    Age  Location  Sales  Profit
# 0             False  False   False  False     False  False   False
# 1             False  False   False  False     False  False   False
# 2             False  False   False  False     False  False   False
# 3             False  False   False  False     False  False   False
# 4             False  False   False  False     False  False   False
# 5             False  False   False  False     False  False   False
# 6             False  False   False  False     False  False   False
# 7             False  False   False  False     False  False   False
# 8             False  False   False  False     False  False   False
# 9             False  False   False  False     False  False   False
# 10            False  False   False  False     False  False   False
# 11            False  False   False  False     False  False   False
# 12            False  False   False  False     False  False   False
# ...

# %%
data1.isnull().any()
# Out:
# Sales Executive    False
# Name               False
# Gender             False
# Age                False
# Location           False
# Sales              False
# Profit             False
# dtype: bool

# %%
data1.isnull().sum()
# Out:
# Sales Executive    0
# Name               0
# Gender             0
# Age                0
# Location           0
# Sales              0
# Profit             0
# dtype: int64

# %%
data1.mean()
# Out:
# Sales Executive    10.50000
# Age                24.60000
# Sales              43.55000
# Profit              0.49104
# dtype: float64

# %%
data1.max()
# Out:
# Sales Executive         20
# Name                 Vijay
# Gender                Male
# Age                     30
# Location            Mumbai
# Sales                   77
# Profit             0.98802
# dtype: object

# %% [markdown]
# ### Merge / Join Dataframe

# %%
data8 = {"emp_id":["1","2","3","4","5"],"emp_name":["Ajay","Vijay","Atul","Sneha","Ravi"]}
data8_df = pd.DataFrame(data8,columns=['emp_id','emp_name'])

# %%
data8_df.dtypes
# Out:
# emp_id      object
# emp_name    object
# dtype: object

# %%
data8
# Out:
# {'emp_id': ['1', '2', '3', '4', '5'],
#  'emp_name': ['Ajay', 'Vijay', 'Atul', 'Sneha', 'Ravi']}

# %%
data8_df
# Out:
#   emp_id emp_name
# 0      1     Ajay
# 1      2    Vijay
# 2      3     Atul
# 3      4    Sneha
# 4      5     Ravi

# %%
data9 = {"emp_id":["6","7","8","9","10"],"emp_name":["Vimal","Rani","Sirisha","Ashok","Pavan"]}
data9_df = pd.DataFrame(data9,columns=['emp_id','emp_name'])

# %%
data9
# Out:
# {'emp_id': ['6', '7', '8', '9', '10'],
#  'emp_name': ['Vimal', 'Rani', 'Sirisha', 'Ashok', 'Pavan']}

# %%
data9_df
# Out:
#   emp_id emp_name
# 0      6    Vimal
# 1      7     Rani
# 2      8  Sirisha
# 3      9    Ashok
# 4     10    Pavan

# %%
df = pd.concat([data8_df,data9_df])
df
# Out:
#   emp_id emp_name
# 0      1     Ajay
# 1      2    Vijay
# 2      3     Atul
# 3      4    Sneha
# 4      5     Ravi
# 0      6    Vimal
# 1      7     Rani
# 2      8  Sirisha
# 3      9    Ashok
# 4     10    Pavan

# %%
print (pd.merge(data8_df,data9_df,on='emp_id',how='left'))
# Out:
#   emp_id emp_name_x emp_name_y
# 0      1       Ajay        NaN
# 1      2      Vijay        NaN
# 2      3       Atul        NaN
# 3      4      Sneha        NaN
# 4      5       Ravi        NaN

# %%
print (pd.merge(data8_df,data9_df,on='emp_id',how='right'))
# Out:
#   emp_id emp_name_x emp_name_y
# 0      6        NaN      Vimal
# 1      7        NaN       Rani
# 2      8        NaN    Sirisha
# 3      9        NaN      Ashok
# 4     10        NaN      Pavan

# %%
#Inner join

print (pd.merge(data8_df,data9_df,on='emp_id',how='inner'))
# Out:
# Empty DataFrame
# Columns: [emp_id, emp_name_x, emp_name_y]
# Index: []

# %%
print (pd.merge(data8_df,data9_df,on='emp_id',how='outer'))
# Out:
#   emp_id emp_name_x emp_name_y
# 0      1       Ajay        NaN
# 1      2      Vijay        NaN
# 2      3       Atul        NaN
# 3      4      Sneha        NaN
# 4      5       Ravi        NaN
# 5      6        NaN      Vimal
# 6      7        NaN       Rani
# 7      8        NaN    Sirisha
# 8      9        NaN      Ashok
# 9     10        NaN      Pavan

# %%
data1.groupby(['Location','Sales']).max()
# Out:
#                  Sales Executive       Name  Gender  Age    Profit
# Location  Sales
# Bangalore 11                   3      Vijay    Male   20  0.577858
#           26                   7      Karan    Male   24  0.560716
#           34                  15     Swetha  Female   21  0.988020
#           36                  11    Lakshmi  Female   19  0.366823
#           40                  16  Aishwarya  Female   24  0.157776
#           77                   4     Ramesh    Male   27  0.169468
# Hyderabad 29                  19    Haritha  Female   24  0.540928
#           50                   1     Mahesh    Male   25  0.094004
#           51                  14     Sruthi  Female   26  0.985413
#           52                   6     Harish    Male   24  0.307628
#           68                  20     Swathi  Female   25  0.224042
#           69                  13     Sravya  Female   26  0.655166
#           72                  12      Roopa  Female   24  0.609996
# ...

# %%
data1.columns
# Out:
# Index(['Sales Executive', 'Name', 'Gender', 'Age', 'Location', 'Sales',
#        'Profit'],
#       dtype='object')

# %%
data1.groupby(['Location','Sales']).count()
# Out:
#                  Sales Executive  Name  Gender  Age  Profit
# Location  Sales
# Bangalore 11                   1     1       1    1       1
#           26                   1     1       1    1       1
#           34                   1     1       1    1       1
#           36                   1     1       1    1       1
#           40                   1     1       1    1       1
#           77                   1     1       1    1       1
# Hyderabad 29                   1     1       1    1       1
#           50                   1     1       1    1       1
#           51                   1     1       1    1       1
#           52                   1     1       1    1       1
#           68                   1     1       1    1       1
#           69                   1     1       1    1       1
#           72                   1     1       1    1       1
#           75                   1     1       1    1       1
# ...

# %%
pd.pivot_table(data1,index=['Location'])
# Out:
#                  Age    Profit      Sales  Sales Executive
# Location
# Bangalore  22.500000  0.470110  37.333333         9.333333
# Hyderabad  24.500000  0.543219  58.250000        10.875000
# Mumbai     26.833333  0.442396  30.166667        11.166667

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
# Sales Executive    20 non-null int64
# Name               20 non-null object
# Gender             20 non-null object
# Age                20 non-null int64
# Location           20 non-null object
# Sales              20 non-null int64
# Profit             20 non-null float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.2+ KB

# %%
data1.describe()
# Out:
#        Sales Executive        Age      Sales     Profit
# count         20.00000  20.000000  20.000000  20.000000
# mean          10.50000  24.600000  43.550000   0.491040
# std            5.91608   2.835861  19.974918   0.281571
# min            1.00000  19.000000  11.000000   0.094004
# 25%            5.75000  23.750000  28.750000   0.257428
# 50%           10.50000  24.000000  38.000000   0.481846
# 75%           15.25000  26.250000  56.000000   0.645825
# max           20.00000  30.000000  77.000000   0.988020

# %%
data1.describe().transpose()
# Out:
#                  count      mean        std        min        25%        50%  \
# Sales Executive   20.0  10.50000   5.916080   1.000000   5.750000  10.500000
# Age               20.0  24.60000   2.835861  19.000000  23.750000  24.000000
# Sales             20.0  43.55000  19.974918  11.000000  28.750000  38.000000
# Profit            20.0   0.49104   0.281571   0.094004   0.257428   0.481846
#
#                        75%       max
# Sales Executive  15.250000  20.00000
# Age              26.250000  30.00000
# Sales            56.000000  77.00000
# Profit            0.645825   0.98802

# %%
data1.shape
# Out:
# (20, 7)

# %%
data1.dtypes
# Out:
# Sales Executive      int64
# Name                object
# Gender              object
# Age                  int64
# Location            object
# Sales                int64
# Profit             float64
# dtype: object

# %%
data1['Gender'].value_counts()
# Out:
# Female    12
# Male       8
# Name: Gender, dtype: int64

# %%
data1['Location'].value_counts()
# Out:
# Hyderabad    8
# Bangalore    6
# Mumbai       6
# Name: Location, dtype: int64

# %%
data1[data1['Gender'].str.contains('Male')]
# Out:
#    Sales Executive      Name Gender  Age   Location  Sales    Profit
# 0                1    Mahesh   Male   25  Hyderabad     50  0.094004
# 1                2    Suresh   Male   22  Hyderabad     75  0.928577
# 2                3     Vijay   Male   20  Bangalore     11  0.577858
# 3                4    Ramesh   Male   27  Bangalore     77  0.169468
# 4                5  Jagadish   Male   28     Mumbai     45  0.417484
# 5                6    Harish   Male   24  Hyderabad     52  0.307628
# 6                7     Karan   Male   24  Bangalore     26  0.560716
# 7                8      Raju   Male   23     Mumbai     24  0.759146

# %%
data1[data1['Gender'].str.contains('Male')].count()
# Out:
# Sales Executive    8
# Name               8
# Gender             8
# Age                8
# Location           8
# Sales              8
# Profit             8
# dtype: int64

# %%
data1[data1['Gender'].str.contains('Male')]
# Out:
#    Sales Executive      Name Gender  Age   Location  Sales ( in Rs)
# 0                1    Mahesh   Male   25  Hyderabad              50
# 1                2    Suresh   Male   22  Hyderabad              75
# 2                3     Vijay   Male   20  Bangalore              11
# 3                4    Ramesh   Male   27  Bangalore              77
# 4                5  Jagadish   Male   28     Mumbai              45
# 5                6    Harish   Male   24  Hyderabad              52
# 6                7     Karan   Male   24  Bangalore              26
# 7                8      Raju   Male   23     Mumbai              24

# %%
data1[data1['Gender'].str.contains('Male')]['Name']
# Out:
# 0      Mahesh
# 1      Suresh
# 2       Vijay
# 3      Ramesh
# 4    Jagadish
# 5      Harish
# 6       Karan
# 7        Raju
# Name: Name, dtype: object

# %%
data1[data1['Gender'].str.contains('Male')][['Gender', 'Sales']]
# Out:
#   Gender  Sales
# 0   Male     50
# 1   Male     75
# 2   Male     11
# 3   Male     77
# 4   Male     45
# 5   Male     52
# 6   Male     26
# 7   Male     24

# %%
data1[data1['Gender'].str.contains('Female')]
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales    Profit
# 8                 9       Maya  Female   24     Mumbai     28  0.642712
# 9                10       Rani  Female   30     Mumbai     31  0.422763
# 10               11    Lakshmi  Female   19  Bangalore     36  0.366823
# 11               12      Roopa  Female   24  Hyderabad     72  0.609996
# 12               13     Sravya  Female   26  Hyderabad     69  0.655166
# 13               14     Sruthi  Female   26  Hyderabad     51  0.985413
# 14               15     Swetha  Female   21  Bangalore     34  0.988020
# 15               16  Aishwarya  Female   24  Bangalore     40  0.157776
# 16               17    Madhavi  Female   29     Mumbai     18  0.143716
# 17               18     Rajini  Female   27     Mumbai     35  0.268556
# 18               19    Haritha  Female   24  Hyderabad     29  0.540928
# 19               20     Swathi  Female   25  Hyderabad     68  0.224042

# %%
data1[data1['Gender'].str.contains('Female')][['Name','Location','Sales']]
# Out:
#          Name   Location  Sales
# 8        Maya     Mumbai     28
# 9        Rani     Mumbai     31
# 10    Lakshmi  Bangalore     36
# 11      Roopa  Hyderabad     72
# 12     Sravya  Hyderabad     69
# 13     Sruthi  Hyderabad     51
# 14     Swetha  Bangalore     34
# 15  Aishwarya  Bangalore     40
# 16    Madhavi     Mumbai     18
# 17     Rajini     Mumbai     35
# 18    Haritha  Hyderabad     29
# 19     Swathi  Hyderabad     68

# %% [raw]
# data1[data1['Gender'].str.contains('Female')] & data1[data1['Location'].str.contains('Hyderabad')][['Name','Sales']]

# %%
data1[data1['Location'].str.contains('Hyderabad')][['Name','Sales']]
# Out:
#        Name  Sales
# 0    Mahesh     50
# 1    Suresh     75
# 5    Harish     52
# 11    Roopa     72
# 12   Sravya     69
# 13   Sruthi     51
# 18  Haritha     29
# 19   Swathi     68

# %%
data1[data1['Sales'] > 50  & data1['Location'].str.contains('Hyderabad')]
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales    Profit
# 0                 1     Mahesh    Male   25  Hyderabad     50  0.094004
# 1                 2     Suresh    Male   22  Hyderabad     75  0.928577
# 2                 3      Vijay    Male   20  Bangalore     11  0.577858
# 3                 4     Ramesh    Male   27  Bangalore     77  0.169468
# 4                 5   Jagadish    Male   28     Mumbai     45  0.417484
# 5                 6     Harish    Male   24  Hyderabad     52  0.307628
# 6                 7      Karan    Male   24  Bangalore     26  0.560716
# 7                 8       Raju    Male   23     Mumbai     24  0.759146
# 8                 9       Maya  Female   24     Mumbai     28  0.642712
# 9                10       Rani  Female   30     Mumbai     31  0.422763
# 10               11    Lakshmi  Female   19  Bangalore     36  0.366823
# 11               12      Roopa  Female   24  Hyderabad     72  0.609996
# ...

# %% [markdown]
# ## Distribution Analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Histogram - Frequency and consistancy
#
# ## Boxplot - Avg, Outliers, Percentile Data present

# %%
data1['Age'].hist(bins=10)

# %%
data1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales    Profit
# 0                 1     Mahesh    Male   25  Hyderabad     50  0.094004
# 1                 2     Suresh    Male   22  Hyderabad     75  0.928577
# 2                 3      Vijay    Male   20  Bangalore     11  0.577858
# 3                 4     Ramesh    Male   27  Bangalore     77  0.169468
# 4                 5   Jagadish    Male   28     Mumbai     45  0.417484
# 5                 6     Harish    Male   24  Hyderabad     52  0.307628
# 6                 7      Karan    Male   24  Bangalore     26  0.560716
# 7                 8       Raju    Male   23     Mumbai     24  0.759146
# 8                 9       Maya  Female   24     Mumbai     28  0.642712
# 9                10       Rani  Female   30     Mumbai     31  0.422763
# 10               11    Lakshmi  Female   19  Bangalore     36  0.366823
# 11               12      Roopa  Female   24  Hyderabad     72  0.609996
# ...

# %%
data1['Age'].unique
# Out:
# <bound method Series.unique of 0     25
# 1     22
# 2     20
# 3     27
# 4     28
# 5     24
# 6     24
# 7     23
# 8     24
# 9     30
# 10    19
# 11    24
# 12    26
# 13    26
# 14    21
# 15    24
# 16    29
# 17    27
# 18    24
# 19    25
# Name: Age, dtype: int64>

# %%
data1['Age'].hist(bins=10)

# %%
data1['Sales'].hist(bins=10)

# %%
data1['Sales'].value_counts()
# Out:
# 31    1
# 18    1
# 34    1
# 35    1
# 11    1
# 69    1
# 72    1
# 36    1
# 75    1
# 77    1
# 50    1
# 51    1
# 52    1
# 68    1
# 40    1
# 24    1
# 45    1
# 28    1
# 29    1
# 26    1
# Name: Sales, dtype: int64

# %%
data1.boxplot(column='Sales')

# %%
data1.describe()
# Out:
#        Sales Executive        Age      Sales     Profit
# count         20.00000  20.000000  20.000000  20.000000
# mean          10.50000  24.600000  43.550000   0.491040
# std            5.91608   2.835861  19.974918   0.281571
# min            1.00000  19.000000  11.000000   0.094004
# 25%            5.75000  23.750000  28.750000   0.257428
# 50%           10.50000  24.000000  38.000000   0.481846
# 75%           15.25000  26.250000  56.000000   0.645825
# max           20.00000  30.000000  77.000000   0.988020

# %%
data1.boxplot(column='Age')

# %% [markdown]
# ## Box Plot
#
# # laft end is 0 percentile %
# # right end is 100 percentile %
# # It takes as 5 divisions (min,q1,q2,q3,max)
#
# ##  Normal distribution is -3 to +3
# ## If it is beyond the range then we call them as outliers

# %%
data1['Age'].hist(bins=5)

# %%
data1['Age'].value_counts()
# Out:
# 24    6
# 27    2
# 26    2
# 25    2
# 30    1
# 29    1
# 28    1
# 23    1
# 22    1
# 21    1
# 20    1
# 19    1
# Name: Age, dtype: int64

# %%
data1.boxplot(column='Age')

# %% [markdown]
# ## find median first
# ### q1- 25% to q3- 75%
# ### for 0 percentile is -> q1-1.5 * IQR is 19
# ### for 100 percentile is -> q3+1.5 * IQR is 31
#
# ### IQR is q3-q1 = 26.5-23.5=3
# ### comparision between two Median,IQR, (range) 0&100, Outliers.
# ### The Avg value and Outliers

# %%
data11=pd.read_csv("bikebuyer.csv")
data11
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %% [markdown]
# ### Bi Variate Analysis

# %%
data1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales    Profit
# 0                 1     Mahesh    Male   25  Hyderabad     50  0.094004
# 1                 2     Suresh    Male   22  Hyderabad     75  0.928577
# 2                 3      Vijay    Male   20  Bangalore     11  0.577858
# 3                 4     Ramesh    Male   27  Bangalore     77  0.169468
# 4                 5   Jagadish    Male   28     Mumbai     45  0.417484
# 5                 6     Harish    Male   24  Hyderabad     52  0.307628
# 6                 7      Karan    Male   24  Bangalore     26  0.560716
# 7                 8       Raju    Male   23     Mumbai     24  0.759146
# 8                 9       Maya  Female   24     Mumbai     28  0.642712
# 9                10       Rani  Female   30     Mumbai     31  0.422763
# 10               11    Lakshmi  Female   19  Bangalore     36  0.366823
# 11               12      Roopa  Female   24  Hyderabad     72  0.609996
# ...

# %%
plt.figure(figsize=(25,25))
data1.boxplot(column ='Sales', by = 'Location')

# %% [markdown]
# ## Interpretation
# - Analysis shows the max sales is near to 80
# - Max sales valeu is 11 at an age 20
# - Median sale somewhere near to 40 (around 34)
# - Age grp 24 is performing avg sales for the company
# - Age grp 27 is performing best sales at the company
# - Age has +ve crrelation over sales
# - Median sale value of Bangalore is higher than Mumbai
# - Least and Highest sales happened in bangalore
# - Region Hyd attributes to increased sales value making it a prospective sales horizon
# - Male have generated least and highest sales
# - Median sale value of males is higher than female
# - sales distribution appears uniform for all three region with a sale value ranging from 25 to 75. Hence Bangalore region attributes to outliers in sale values lying below and above the normal sale distribution.

# %%
plt.figure(figsize=(25,25))
data1.boxplot(column ='Sales', by = 'Gender')

# %%
data1['Age'].hist(bins=10)

# %%
data1.boxplot(column='Age')

# %% [markdown]
# ## Interpretation
#
# - At the Age 24 are doing the average sales
# - At the age 27 are doing the best sales

# %%
data1['Gender'].value_counts()
# Out:
# Female    12
# Male       8
# Name: Gender, dtype: int64

# %%
data1['Location'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai'], dtype=object)

# %%
data1['Location'].nunique()
# Out:
# 3

# %%
data1['Sales'].value_counts()
# Out:
# 31    1
# 18    1
# 34    1
# 35    1
# 11    1
# 69    1
# 72    1
# 36    1
# 75    1
# 77    1
# 50    1
# 51    1
# 52    1
# 68    1
# 40    1
# 24    1
# 45    1
# 28    1
# 29    1
# 26    1
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(20,20))
data1.boxplot(column ='Sales', by = 'Age')

# %% [markdown]
# ### Avg,IQR,median
#
# #### Analysis shows the maximum sale is near to 80 (i.e 77) by an age 27
# #### minimum sale value is 11 at an age 20
# #### median sale is somewhare near to the 40 (around 34)
# #### Age group

# %%
data1['Age'].value_counts()
# Out:
# 24    6
# 27    2
# 26    2
# 25    2
# 30    1
# 29    1
# 28    1
# 23    1
# 22    1
# 21    1
# 20    1
# 19    1
# Name: Age, dtype: int64

# %%
data1.boxplot(column='Sales')

# %%
plt.figure(figsize=(25,25))
data1.boxplot(column ='Sales', by = 'Gender')

# %%
data1.hist(column = "Sales", by = "Gender", bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11602ecc0>,
# ...
#       dtype=object)

# %%
data1.loc[(data1["Gender"]=="Female")&(data1["Location"]=="Hyderabad"),["Name","Location"]]
# Out:
#        Name   Location
# 11    Roopa  Hyderabad
# 12   Sravya  Hyderabad
# 13   Sruthi  Hyderabad
# 18  Haritha  Hyderabad
# 19   Swathi  Hyderabad

# %%
pd.crosstab(data1["Sales"],data1["Gender"],margins=True)
# Out:
# Gender  Female  Male  All
# Sales
# 11           0     1    1
# 18           1     0    1
# 24           0     1    1
# 26           0     1    1
# 28           1     0    1
# 29           1     0    1
# 31           1     0    1
# 34           1     0    1
# 35           1     0    1
# 36           1     0    1
# 40           1     0    1
# 45           0     1    1
# 50           0     1    1
# 51           1     0    1
# 52           0     1    1
# 68           1     0    1
# 69           1     0    1
# 72           1     0    1
# 75           0     1    1
# 77           0     1    1
# All         12     8   20

# %%
import pandas as pd
pd.pivot_table(data1.index=['Location'])
# Out:
#   File "<ipython-input-91-c32019e7139c>", line 2
#     pd.pivot_table(data1.index=['Location'])
#                   ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# ###
