# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/rajusunkara/Downloads/innomatics/dataframe'

# %%
os.chdir("/Users/rajusunkara/Downloads/innomatics/dataframe/dataframe")

# %%
os.getcwd()
# Out:
# '/Users/rajusunkara/Downloads/innomatics/dataframe/dataframe'

# %% [markdown]
# ## Given data is a categorical form
# ### Which classifying into will buy or not buy

# %%
data_1 = pd.read_csv("bikebuyer.csv")
data_1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
data_1.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Yearly Income', 'Children',
#        'Education', 'Occupation', 'Home Owner', 'Cars', 'Commute Distance',
#        'Region', 'Age', 'Bike Buyer'],
#       dtype='object')

# %%
data_1['Commute Distance'].fillna(value=data_1['Commute Distance'].mean())
# Out:
# 0        1.000000
# 1        1.000000
# 2        2.000000
# 3        5.000000
# 4        1.000000
# 5        1.000000
# 6        4.210103
# 7        1.000000
# 8       10.000000
# 9        1.000000
# 10       2.000000
# 11      11.000000
# 12       1.000000
# 13       1.000000
# 14       1.000000
# 15       1.000000
# 16       2.000000
# 17       1.000000
# 18       2.000000
# 19       6.000000
# 20       1.000000
# 21      12.000000
# 22       1.000000
# 23       4.210103
# 24       1.000000
# 25       1.000000
# 26       1.000000
# 27       9.000000
# 28       5.000000
# 29       1.000000
#           ...
# 6967     2.000000
# 6968     1.000000
# 6969     1.000000
# 6970     2.000000
# 6971     7.000000
# 6972     8.000000
# 6973     9.000000
# 6974     2.000000
# 6975     3.000000
# 6976     5.000000
# 6977     6.000000
# 6978     7.000000
# 6979     1.000000
# 6980     2.000000
# 6981     1.000000
# 6982     1.000000
# 6983     2.000000
# 6984     7.000000
# 6985     8.000000
# ...

# %%
data_1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %% [markdown]
# ## PPT on EDA
#
# ### Lifecycle  of a Datascience
#
# ## 1)Business Problem - set 15 variabl problems in online in retail
# ### Sources: Kaggle , USA
#
# ## 2) Data Collection
# ## 3) Data Cleaning
# ## 4) EDA-Exploratory Data Analysis
# ### independent - x and dependent - y
# ### Machine Learning - Supervise (a dependent and one or more independent variable),
# ### Unsupervise(more than one dependent variable)
# ### use all functions in the pandas EDA, conditions, pivot
# ## 5) Feature Engineering
# ## 6) Machine Learning
# ## 7) Performance Evaluation
# ## 8) Communicate to the client
# ### it is a recommondation-unsup, automation and Predict-sup

# %%
data_1['Age'].hist(bins=20)

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6997 entries, 0 to 6996
# Data columns (total 13 columns):
# ID                  6996 non-null float64
# Marital Status      6981 non-null object
# Gender              6968 non-null object
# Yearly Income       6997 non-null int64
# Children            6979 non-null float64
# Education           6997 non-null object
# Occupation          6997 non-null object
# Home Owner          6997 non-null object
# Cars                6997 non-null int64
# Commute Distance    6968 non-null float64
# Region              6997 non-null object
# Age                 6997 non-null int64
# Bike Buyer          6997 non-null object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 710.7+ KB

# %%
data_1 = pd.read_csv("bikebuyer.csv")
data_1.shape
# Out:
# (6997, 13)

# %%
# df['A'].fillna(value=df['A'].mean())

data_1.head()
# Out:
#         ID Marital Status  Gender  Yearly Income  Children        Education  \
# 0  22711.0         Single    Male          30000       0.0  Partial College
# 1  13555.0        Married  Female          40000       0.0  Graduate Degree
# 2      NaN        Married    Male         160000       5.0  Partial College
# 3      2.0         Single    Male         160000       0.0  Graduate Degree
# 4  25410.0            NaN  Female          70000       2.0        Bachelors
#
#        Occupation Home Owner  Cars  Commute Distance         Region  Age  \
# 0        Clerical         No     1               1.0         Europe   33
# 1        Clerical        Yes     0               1.0         Europe   37
# 2    Professional         No     3               2.0         Europe   55
# 3      Management        Yes     2               5.0        Pacific   47
# 4  Skilled Manual         No     1               1.0  North America   38
#
#   Bike Buyer
# 0        Yes
# 1        Yes
# 2         No
# ...

# %%
data_1["Education"].value_counts()
# Out:
# Partial College        1932
# Bachelors              1870
# High School            1313
# Graduate Degree        1272
# Partial High School     610
# Name: Education, dtype: int64

# %%
data_1["Education"].unique()
# Out:
# array(['Partial College', 'Graduate Degree', 'Bachelors', 'High School',
#        'Partial High School'], dtype=object)

# %%
data_1.dtypes
# Out:
# ID                  float64
# Marital Status       object
# Gender               object
# Yearly Income         int64
# Children            float64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                  int64
# Commute Distance    float64
# Region               object
# Age                   int64
# Bike Buyer           object
# dtype: object

# %%
data_1.isnull().sum()
# Out:
# ID                   1
# Marital Status      16
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data_1["Marital Status"].value_counts()
# Out:
# Married    4133
# Single     2848
# Name: Marital Status, dtype: int64

# %%
data_1['Marital Status'].fillna('Married',inplace=True)

# %%
data_1.isnull().sum()
# Out:
# ID                   1
# Marital Status       0
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data_1["Gender"].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
data_1['Gender'].fillna('Male',inplace=True)

# %%
data_1.isnull().sum()
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data_1['Commute Distance']
# Out:
# 0        1.0
# 1        1.0
# 2        2.0
# 3        5.0
# 4        1.0
# 5        1.0
# 6        NaN
# 7        1.0
# 8       10.0
# 9        1.0
# 10       2.0
# 11      11.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       2.0
# 17       1.0
# 18       2.0
# 19       6.0
# 20       1.0
# 21      12.0
# 22       1.0
# 23       NaN
# 24       1.0
# 25       1.0
# 26       1.0
# 27       9.0
# 28       5.0
# 29       1.0
#         ...
# 6967     2.0
# 6968     1.0
# 6969     1.0
# 6970     2.0
# 6971     7.0
# 6972     8.0
# 6973     9.0
# 6974     2.0
# 6975     3.0
# 6976     5.0
# 6977     6.0
# 6978     7.0
# 6979     1.0
# 6980     2.0
# 6981     1.0
# 6982     1.0
# 6983     2.0
# 6984     7.0
# 6985     8.0
# 6986     9.0
# 6987     2.0
# 6988     3.0
# 6989     5.0
# 6990     6.0
# 6991     7.0
# 6992     1.0
# 6993     2.0
# 6994     1.0
# 6995     1.0
# 6996     2.0
# Name: Commute Distance, Length: 6997, dtype: float64

# %%
data_1['Commute Distance'].fillna(value=data_1['Commute Distance'].mean())
# Out:
# 0        1.000000
# 1        1.000000
# 2        2.000000
# 3        5.000000
# 4        1.000000
# 5        1.000000
# 6        4.210103
# 7        1.000000
# 8       10.000000
# 9        1.000000
# 10       2.000000
# 11      11.000000
# 12       1.000000
# 13       1.000000
# 14       1.000000
# 15       1.000000
# 16       2.000000
# 17       1.000000
# 18       2.000000
# 19       6.000000
# 20       1.000000
# 21      12.000000
# 22       1.000000
# 23       4.210103
# 24       1.000000
# 25       1.000000
# 26       1.000000
# 27       9.000000
# 28       5.000000
# 29       1.000000
#           ...
# 6967     2.000000
# 6968     1.000000
# 6969     1.000000
# 6970     2.000000
# 6971     7.000000
# 6972     8.000000
# 6973     9.000000
# 6974     2.000000
# 6975     3.000000
# 6976     5.000000
# 6977     6.000000
# 6978     7.000000
# 6979     1.000000
# 6980     2.000000
# 6981     1.000000
# 6982     1.000000
# 6983     2.000000
# 6984     7.000000
# 6985     8.000000
# ...

# %%
data_1.isnull().sum()
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data_1['Children'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
data_1['Children'].fillna(0,inplace=True)

# %%
data_1.isnull().sum()
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children             0
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data_1['Commute Distance'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
data_1['Commute Distance'].fillna(1,inplace=True)

# %%
data_1.isnull().sum()
# Out:
# ID                  1
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
data_1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0        Married  Female          70000       2.0
# 5         4.0        Married    Male         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0        Married  Female              0       0.0
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single    Male          60000       0.0
# 13    14902.0        Married  Female          40000       0.0
# ...

# %%
data_1['ID'].nunique()
# Out:
# 6996

# %%
data_1['ID'].max()
# Out:
# 29476.0

# %%
data_1['ID'].min()
# Out:
# 2.0

# %%
data_1['ID'].max()+1
# Out:
# 29477.0

# %%
#data_1['ID'].fillna((data_1['ID'].max()+1),inplace=True)
data_1.at[2, 'ID'] = 1

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6997 entries, 0 to 6996
# Data columns (total 13 columns):
# ID                  6997 non-null float64
# Marital Status      6997 non-null object
# Gender              6997 non-null object
# Yearly Income       6997 non-null int64
# Children            6997 non-null float64
# Education           6997 non-null object
# Occupation          6997 non-null object
# Home Owner          6997 non-null object
# Cars                6997 non-null int64
# Commute Distance    6997 non-null float64
# Region              6997 non-null object
# Age                 6997 non-null int64
# Bike Buyer          6997 non-null object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 710.7+ KB

# %%
data_1.head()
# Out:
#         ID Marital Status  Gender  Yearly Income  Children        Education  \
# 0  22711.0         Single    Male          30000       0.0  Partial College
# 1  13555.0        Married  Female          40000       0.0  Graduate Degree
# 2      1.0        Married    Male         160000       5.0  Partial College
# 3      2.0         Single    Male         160000       0.0  Graduate Degree
# 4  25410.0        Married  Female          70000       2.0        Bachelors
#
#        Occupation Home Owner  Cars  Commute Distance         Region  Age  \
# 0        Clerical         No     1               1.0         Europe   33
# 1        Clerical        Yes     0               1.0         Europe   37
# 2    Professional         No     3               2.0         Europe   55
# 3      Management        Yes     2               5.0        Pacific   47
# 4  Skilled Manual         No     1               1.0  North America   38
#
#   Bike Buyer
# 0        Yes
# 1        Yes
# 2         No
# ...

# %%
data_1.isnull().sum()
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
data_1.groupby(['Region','Age']).max()
# Out:
#                   ID Marital Status  Gender  Yearly Income  Children  \
# Region  Age
# Europe  25   21911.0         Single    Male          20000       0.0
#         26   26211.0         Single    Male          30000       4.0
#         27   29409.0         Single    Male          30000       5.0
#         28   29413.0         Single    Male          30000       5.0
#         29   29419.0         Single    Male          30000       5.0
#         30   29423.0         Single    Male          40000       4.0
#         31   29430.0         Single    Male          40000       1.0
#         32   29428.0         Single    Male          40000       1.0
#         33   28555.0         Single    Male          50000       2.0
#         34   27175.0         Single    Male          40000       2.0
#         35   27179.0         Single    Male          40000       2.0
#         36   28756.0         Single    Male          50000       2.0
# ...

# %%
pd.pivot_table(data_1,index=['Region'])
# Out:
#                      Age      Cars  Children  Commute Distance            ID  \
# Region
# Europe         44.567748  1.386450  1.183683          4.241412  17868.652672
# North America  45.788627  1.520386  0.910676          4.174624  17594.459764
# Pacific        43.906223  2.156010  1.604433          4.187553  17983.996590
#
#                Yearly Income
# Region
# Europe          42228.053435
# North America   63312.768240
# Pacific         63452.685422

# %%
data_1['Region'].unique()
# Out:
# array(['Europe', 'Pacific', 'North America'], dtype=object)

# %%
data_1[data_1['Home Owner'].str.contains('No')]
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 2         1.0        Married    Male         160000       5.0
# 4     25410.0        Married  Female          70000       2.0
# 7     11085.0         Single  Female          60000       0.0
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single    Male          60000       0.0
# 15    11094.0         Single    Male          70000       0.0
# 19    11098.0        Married  Female          60000       0.0
# 25    23612.0         Single  Female          90000       0.0
# 28    11118.0         Single    Male          80000       0.0
# 31    11104.0        Married    Male          70000       0.0
# 32    15834.0         Single  Female          40000       0.0
# ...

# %%
# Visualize the data in plot

# %matplotlib inline
data_1.plot()

# %%
data_1.agg(['count', 'size', 'nunique'])
# Out:
#            ID  Marital Status  Gender  Yearly Income  Children  Education  \
# count    6997            6997    6997           6997      6997       6997
# size     6997            6997    6997           6997      6997       6997
# nunique  6997               2       2             17         6          5
#
#          Occupation  Home Owner  Cars  Commute Distance  Region   Age  \
# count          6997        6997  6997              6997    6997  6997
# size           6997        6997  6997              6997    6997  6997
# nunique           5           2     5                13       3    68
#
#          Bike Buyer
# count          6997
# size           6997
# nunique           2

# %%
data_1.groupby('Education').agg(['count', 'size', 'nunique'])
# Out:
#                        ID               Marital Status               Gender  \
#                     count  size nunique          count  size nunique  count
# Education
# Bachelors            1870  1870    1870           1870  1870       2   1870
# Graduate Degree      1272  1272    1272           1272  1272       2   1272
# High School          1313  1313    1313           1313  1313       2   1313
# Partial College      1932  1932    1932           1932  1932       2   1932
# Partial High School   610   610     610            610   610       2    610
#
#                                   Yearly Income   ...   Commute Distance  \
#                      size nunique         count   ...            nunique
# Education                                         ...
# Bachelors            1870       2          1870   ...                 13
# Graduate Degree      1272       2          1272   ...                 13
# High School          1313       2          1313   ...                 12
# ...

# %%
data_1.groupby('Education').agg(['count', 'size', 'nunique']).stack()
# Out:
#                                ID  Marital Status  Gender  Yearly Income  \
# Education
# Bachelors           count    1870            1870    1870           1870
#                     size     1870            1870    1870           1870
#                     nunique  1870               2       2             17
# Graduate Degree     count    1272            1272    1272           1272
#                     size     1272            1272    1272           1272
#                     nunique  1272               2       2             16
# High School         count    1313            1313    1313           1313
#                     size     1313            1313    1313           1313
#                     nunique  1313               2       2             16
# Partial College     count    1932            1932    1932           1932
#                     size     1932            1932    1932           1932
#                     nunique  1932               2       2             17
# ...

# %%
data_1.groupby(['Age','Yearly Income']).Age.mean()
# Out:
# Age  Yearly Income
# 25   20000            25
#      30000            25
#      40000            25
#      60000            25
# 26   10000            26
#      20000            26
#      30000            26
#      40000            26
#      60000            26
#      70000            26
# 27   10000            27
#      20000            27
#      30000            27
#      40000            27
#      60000            27
#      70000            27
# 28   10000            28
#      20000            28
#      30000            28
#      40000            28
#      60000            28
#      70000            28
# 29   10000            29
#      20000            29
#      30000            29
#      40000            29
#      60000            29
#      70000            29
#      100000           29
# 30   10000            30
#                       ..
# 77   70000            77
# 78   10000            78
#      20000            78
#      50000            78
# 79   20000            79
# ...

# %%
# Draw a plot based on the mean of the Age

data_1.groupby(['Age']).mean().plot()

# %%
data_1.head()
# Out:
#         ID Marital Status  Gender  Yearly Income  Children        Education  \
# 0  22711.0         Single    Male          30000       0.0  Partial College
# 1  13555.0        Married  Female          40000       0.0  Graduate Degree
# 2      1.0        Married    Male         160000       5.0  Partial College
# 3      2.0         Single    Male         160000       0.0  Graduate Degree
# 4  25410.0        Married  Female          70000       2.0        Bachelors
#
#        Occupation Home Owner  Cars  Commute Distance         Region  Age  \
# 0        Clerical         No     1               1.0         Europe   33
# 1        Clerical        Yes     0               1.0         Europe   37
# 2    Professional         No     3               2.0         Europe   55
# 3      Management        Yes     2               5.0        Pacific   47
# 4  Skilled Manual         No     1               1.0  North America   38
#
#   Bike Buyer
# 0        Yes
# 1        Yes
# 2         No
# ...

# %%
data_1.groupby(['Region','Occupation']).max()
# Out:
#                                    ID Marital Status Gender  Yearly Income  \
# Region        Occupation
# Europe        Clerical        29447.0         Single   Male          40000
#               Management      28920.0         Single   Male         170000
#               Manual          29476.0         Single   Male          30000
#               Professional    28905.0         Single   Male         170000
#               Skilled Manual  29379.0         Single   Male          90000
# North America Clerical        29339.0         Single   Male          40000
#               Management      29263.0         Single   Male         170000
#               Manual          22341.0         Single   Male          30000
#               Professional    29284.0         Single   Male         150000
#               Skilled Manual  29353.0         Single   Male          90000
# Pacific       Clerical        29342.0         Single   Male          40000
# ...

# %%
data_1.groupby(['Region','Occupation']).count()
# Out:
#                                 ID  Marital Status  Gender  Yearly Income  \
# Region        Occupation
# Europe        Clerical         562             562     562            562
#               Management       167             167     167            167
#               Manual           911             911     911            911
#               Professional     293             293     293            293
#               Skilled Manual   163             163     163            163
# North America Clerical         253             253     253            253
#               Management       846             846     846            846
#               Manual            29              29      29             29
#               Professional    1256            1256    1256           1256
#               Skilled Manual  1344            1344    1344           1344
# Pacific       Clerical         148             148     148            148
# ...

# %% [markdown]
# ### Sample DataSets

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data_edu=pd.read_csv("../../data/education/Educational_institutes.csv")
data_edu.head()
# Out:
#    Sl.No            ULB  Private High schools  Private Upper primary schools  \
# 0      1       Adilabad                     8                             10
# 1      2  Andol-Jogipet                     6                              1
# 2      3         Armoor                     8                              0
# 3      4      Atchampet                    10                              3
# 4      5      Badangpet                    27                             16
#
#    Private Primary schools  Government High schools  \
# 0                       13                        7
# 1                        1                        3
# 2                        5                        9
# 3                        2                        4
# 4                        9                        5
#
#    Government Upper primary schools  Government Primary schools  \
# 0                                 8                          11
# ...

# %%
data_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 14 columns):
# Sl.No                                                     72 non-null int64
# ULB                                                       72 non-null object
# Private High schools                                      72 non-null int64
# Private Upper primary schools                             72 non-null int64
# Private Primary schools                                   72 non-null int64
# Government High schools                                   72 non-null int64
# Government Upper primary schools                          72 non-null int64
# Government Primary schools                                72 non-null int64
# Private Junior/Polytechnic Colleges                       72 non-null int64
# Private Degree/Engineering/Post Graduation Colleges       72 non-null int64
# Government Junior/Polytechnic Colleges                    72 non-null int64
# ...

# %%
data_edu['Private High schools'].hist(bins=20)

# %%
data_edu.plot(x= 'ULB',y='Government High schools',kind='Density',grid=True)
plt.title('x vs y')
plt.show()
